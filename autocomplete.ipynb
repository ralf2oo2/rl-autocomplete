# %% [markdown]
# ## RL Autocomplete
#
# In this notebook I'm going to show my process of making a reinforcement learning agent that will guess the next letter in a string and potentially use it for autocomplete. I decided to do this project because I wanted to do a non gaming related reinforcement learning project. I know that there are better ways to do autocomplete but I'm curious if reinforcement learning would work. The project will be using a PPO model that I will create using pytorch and chatgpt. The reason for this choice is because I used a PPO model in my previous project and I want to get a better understanding of how it works

# %% [markdown]
# First I made the pytorch module. Initially I was using convolutional layers in my module but those are usually used for pattern recognision like machine vision. I learned about convolutional layers so it wasn't too bad. I found that most people use linear layers so my module also uses linear layers. If at any point the module seems to be insufficient I will update it.

# %%
import torch.nn as nn

class ActorCritic(nn.Module):

    def __init__(self, nb_actions):
        super().__init__()
        self.head = nn.Sequential(nn.Linear(4, 64), nn.Tanh(), nn.Linear(64, 64), nn.Tanh())
        self.actor = nn.Sequential(nn.Linear(64, nb_actions))
        self.critic = nn.Sequential(nn.Linear(64, 1))
    
    def forward(self, x):
        h = self.head(x)
        return self.actor(h), self.critic(h)

# %% [markdown]
# With the help of chatgpt I made the PPO agent. the parameters are as follows
# - **nb_actions:** the number of actions the agent can take
# - **device:** the device that the model is bein run on
# - **gamma:** discount factor
# - **lam:** GAE(Generalized Advantage Estimation) lambda
# - **clip_eps:** PPO clipping parameter, 0.2 is fine in almost all cases
# - **lr:** learning rate
# - **epochs:** how many times to pass through data per update
# - **batch_size:** size of mini batches
#
# the **get_action_and_value** function takes in a state and returns an action, the log probability of the action and the estimated value of the action
#
# the **compute_gae** function calculates the returns using GAE
#
# the **ppo_update** function performs the policy and value function update

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
from torch.distributions import Categorical

class PPOAgent:
    def __init__(self, nb_actions, device='cpu', gamma=0.99, lam=0.95, clip_eps=0.2, lr=2.5e-4, epochs=4, batch_size=64):
        self.device = device
        self.gamma = gamma
        self.lam = lam
        self.clip_eps = clip_eps
        self.epochs = epochs
        self.batch_size = batch_size

        self.model = ActorCritic(nb_actions).to(device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)

    def get_action_and_value(self, state):
        logits, value = self.model(state)
        dist = Categorical(logits=logits)
        action = dist.sample()
        log_prob = dist.log_prob(action)
        return action, log_prob, value.squeeze(-1)

    def compute_gae(self, rewards, values, dones, next_value):
        values = np.append(values, next_value)
        gae = 0
        returns = []
        for t in reversed(range(len(rewards))):
            delta = rewards[t] + self.gamma * values[t + 1] * (1 - dones[t]) - values[t]
            gae = delta + self.gamma * self.lam * (1 - dones[t]) * gae
            returns.insert(0, gae + values[t])
        return returns

    def ppo_update(self, states, actions, log_probs, returns, values):
        advantages = returns - values
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        for _ in range(self.epochs):
            indices = np.arange(len(states))
            np.random.shuffle(indices)

            for i in range(0, len(states), self.batch_size):
                idx = indices[i:i+self.batch_size]
                s_batch = torch.tensor(states[idx], dtype=torch.float32).to(self.device)
                a_batch = torch.tensor(actions[idx]).to(self.device)
                old_log_probs_batch = torch.tensor(log_probs[idx]).to(self.device)
                ret_batch = torch.tensor(returns[idx], dtype=torch.float32).to(self.device)
                adv_batch = torch.tensor(advantages[idx], dtype=torch.float32).to(self.device)

                logits, value = self.model(s_batch)
                dist = Categorical(logits=logits)
                entropy = dist.entropy().mean()
                new_log_probs = dist.log_prob(a_batch)

                ratio = (new_log_probs - old_log_probs_batch).exp()
                surr1 = ratio * adv_batch
                # Clipping for stability
                surr2 = torch.clamp(ratio, 1.0 - self.clip_eps, 1.0 + self.clip_eps) * adv_batch

                policy_loss = -torch.min(surr1, surr2).mean()
                value_loss = F.mse_loss(value.squeeze(-1), ret_batch)
                loss = policy_loss + 0.5 * value_loss - 0.01 * entropy

                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()

# %% [markdown]
# Before starting on the autocomplete agent I wanted to test if the PPO agent even works. It would be annoying if I didn't know if a bug was caused by my agent or my training. I created a script for loading a gymnasium environment and training the PPO agent. An interesting thing to note from the script is that the agent only gets trained after 50 experiences. this is because of the way PPO works. first the agent will collect an amount of experiences based on the current policy and then the agent gets trained on those experiences. unlike Q-learning, these experiences are discarded after training.

# %%
import gymnasium as gym
import numpy as np
import torch

env = gym.make('CartPole-v1')
agent = PPOAgent(nb_actions=env.action_space.n)

max_episodes = 3000
max_steps = 500

for episode in range(max_episodes):
    state, _ = env.reset()
    states, actions, log_probs, rewards, dones, values = [], [], [], [], [], []

    
    for _ in range(max_steps):
        state_tensor = torch.from_numpy(state).float().unsqueeze(0)
        action_tensor, log_prob, value = agent.get_action_and_value(state_tensor)
        action = int(action_tensor)
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated


        states.append(state)
        actions.append(action)
        log_probs.append(log_prob.item())
        rewards.append(reward)
        dones.append(done)
        values.append(value.item())

        state = next_state
        if done:
            break

    next_state_tensor = torch.tensor(next_state, dtype=torch.float32).unsqueeze(0)
    _, _, next_value = agent.get_action_and_value(next_state_tensor)
    returns = agent.compute_gae(rewards, values, dones, next_value.item())

    agent.ppo_update(
        np.array(states),
        np.array(actions),
        np.array(log_probs),
        np.array(returns),
        np.array(values)
    )

    total_reward = sum(rewards)
    print(f"Episode {episode + 1}: Total Reward = {total_reward}")
# Out:
# Episode 1: Total Reward = 23.0
# Episode 2: Total Reward = 11.0
# Episode 3: Total Reward = 38.0
# Episode 4: Total Reward = 22.0
# Episode 5: Total Reward = 22.0
# Episode 6: Total Reward = 12.0
# Episode 7: Total Reward = 25.0
# Episode 8: Total Reward = 10.0
# Episode 9: Total Reward = 11.0
# Episode 10: Total Reward = 22.0
# Episode 11: Total Reward = 12.0
# Episode 12: Total Reward = 22.0
# Episode 13: Total Reward = 26.0
# Episode 14: Total Reward = 23.0
# Episode 15: Total Reward = 14.0
# Episode 16: Total Reward = 14.0
# Episode 17: Total Reward = 19.0
# Episode 18: Total Reward = 19.0
# Episode 19: Total Reward = 28.0
# Episode 20: Total Reward = 19.0
# Episode 21: Total Reward = 12.0
# Episode 22: Total Reward = 11.0
# Episode 23: Total Reward = 29.0
# Episode 24: Total Reward = 31.0
# Episode 25: Total Reward = 19.0
# Episode 26: Total Reward = 14.0
# Episode 27: Total Reward = 24.0
# Episode 28: Total Reward = 9.0
# Episode 29: Total Reward = 55.0
# Episode 30: Total Reward = 17.0
# Episode 31: Total Reward = 62.0
# Episode 32: Total Reward = 33.0
# Episode 33: Total Reward = 18.0
# Episode 34: Total Reward = 27.0
# Episode 35: Total Reward = 20.0
# Episode 36: Total Reward = 21.0
# Episode 37: Total Reward = 17.0
# Episode 38: Total Reward = 25.0
# Episode 39: Total Reward = 20.0
# Episode 40: Total Reward = 15.0
# Episode 41: Total Reward = 12.0
# Episode 42: Total Reward = 31.0
# Episode 43: Total Reward = 26.0
# Episode 44: Total Reward = 27.0
# Episode 45: Total Reward = 12.0
# Episode 46: Total Reward = 8.0
# Episode 47: Total Reward = 18.0
# Episode 48: Total Reward = 16.0
# Episode 49: Total Reward = 38.0
# Episode 50: Total Reward = 13.0
# Episode 51: Total Reward = 20.0
# Episode 52: Total Reward = 20.0
# Episode 53: Total Reward = 22.0
# Episode 54: Total Reward = 18.0
# Episode 55: Total Reward = 11.0
# Episode 56: Total Reward = 15.0
# Episode 57: Total Reward = 14.0
# Episode 58: Total Reward = 13.0
# Episode 59: Total Reward = 25.0
# Episode 60: Total Reward = 14.0
# Episode 61: Total Reward = 18.0
# Episode 62: Total Reward = 13.0
# Episode 63: Total Reward = 11.0
# Episode 64: Total Reward = 19.0
# Episode 65: Total Reward = 34.0
# Episode 66: Total Reward = 16.0
# Episode 67: Total Reward = 12.0
# Episode 68: Total Reward = 10.0
# Episode 69: Total Reward = 28.0
# Episode 70: Total Reward = 12.0
# Episode 71: Total Reward = 14.0
# Episode 72: Total Reward = 10.0
# Episode 73: Total Reward = 9.0
# Episode 74: Total Reward = 15.0
# Episode 75: Total Reward = 14.0
# Episode 76: Total Reward = 10.0
# Episode 77: Total Reward = 11.0
# Episode 78: Total Reward = 9.0
# Episode 79: Total Reward = 10.0
# Episode 80: Total Reward = 8.0
# Episode 81: Total Reward = 14.0
# Episode 82: Total Reward = 17.0
# Episode 83: Total Reward = 15.0
# Episode 84: Total Reward = 22.0
# Episode 85: Total Reward = 11.0
# Episode 86: Total Reward = 10.0
# Episode 87: Total Reward = 14.0
# Episode 88: Total Reward = 33.0
# Episode 89: Total Reward = 14.0
# Episode 90: Total Reward = 21.0
# Episode 91: Total Reward = 14.0
# Episode 92: Total Reward = 12.0
# Episode 93: Total Reward = 11.0
# Episode 94: Total Reward = 17.0
# Episode 95: Total Reward = 11.0
# Episode 96: Total Reward = 23.0
# Episode 97: Total Reward = 12.0
# Episode 98: Total Reward = 21.0
# Episode 99: Total Reward = 18.0
# Episode 100: Total Reward = 14.0
# Episode 101: Total Reward = 11.0
# Episode 102: Total Reward = 11.0
# Episode 103: Total Reward = 14.0
# Episode 104: Total Reward = 13.0
# Episode 105: Total Reward = 10.0
# Episode 106: Total Reward = 22.0
# Episode 107: Total Reward = 12.0
# Episode 108: Total Reward = 20.0
# Episode 109: Total Reward = 30.0
# Episode 110: Total Reward = 14.0
# Episode 111: Total Reward = 11.0
# Episode 112: Total Reward = 18.0
# Episode 113: Total Reward = 23.0
# Episode 114: Total Reward = 42.0
# Episode 115: Total Reward = 11.0
# Episode 116: Total Reward = 14.0
# Episode 117: Total Reward = 24.0
# Episode 118: Total Reward = 23.0
# Episode 119: Total Reward = 30.0
# Episode 120: Total Reward = 31.0
# Episode 121: Total Reward = 23.0
# Episode 122: Total Reward = 24.0
# Episode 123: Total Reward = 11.0
# Episode 124: Total Reward = 33.0
# Episode 125: Total Reward = 29.0
# Episode 126: Total Reward = 13.0
# Episode 127: Total Reward = 17.0
# Episode 128: Total Reward = 9.0
# Episode 129: Total Reward = 47.0
# Episode 130: Total Reward = 36.0
# Episode 131: Total Reward = 46.0
# Episode 132: Total Reward = 17.0
# Episode 133: Total Reward = 13.0
# Episode 134: Total Reward = 15.0
# Episode 135: Total Reward = 23.0
# Episode 136: Total Reward = 33.0
# Episode 137: Total Reward = 30.0
# Episode 138: Total Reward = 28.0
# Episode 139: Total Reward = 16.0
# Episode 140: Total Reward = 35.0
# Episode 141: Total Reward = 32.0
# Episode 142: Total Reward = 47.0
# Episode 143: Total Reward = 11.0
# Episode 144: Total Reward = 9.0
# Episode 145: Total Reward = 12.0
# Episode 146: Total Reward = 11.0
# Episode 147: Total Reward = 12.0
# Episode 148: Total Reward = 12.0
# Episode 149: Total Reward = 13.0
# Episode 150: Total Reward = 17.0
# Episode 151: Total Reward = 13.0
# Episode 152: Total Reward = 11.0
# Episode 153: Total Reward = 11.0
# Episode 154: Total Reward = 14.0
# Episode 155: Total Reward = 11.0
# Episode 156: Total Reward = 13.0
# Episode 157: Total Reward = 27.0
# Episode 158: Total Reward = 15.0
# Episode 159: Total Reward = 11.0
# Episode 160: Total Reward = 11.0
# Episode 161: Total Reward = 13.0
# Episode 162: Total Reward = 12.0
# Episode 163: Total Reward = 23.0
# Episode 164: Total Reward = 13.0
# Episode 165: Total Reward = 25.0
# Episode 166: Total Reward = 19.0
# Episode 167: Total Reward = 21.0
# Episode 168: Total Reward = 13.0
# Episode 169: Total Reward = 9.0
# Episode 170: Total Reward = 15.0
# Episode 171: Total Reward = 15.0
# Episode 172: Total Reward = 14.0
# Episode 173: Total Reward = 14.0
# Episode 174: Total Reward = 13.0
# Episode 175: Total Reward = 17.0
# Episode 176: Total Reward = 24.0
# Episode 177: Total Reward = 12.0
# Episode 178: Total Reward = 22.0
# Episode 179: Total Reward = 23.0
# Episode 180: Total Reward = 25.0
# Episode 181: Total Reward = 38.0
# Episode 182: Total Reward = 14.0
# Episode 183: Total Reward = 21.0
# Episode 184: Total Reward = 26.0
# Episode 185: Total Reward = 11.0
# Episode 186: Total Reward = 16.0
# Episode 187: Total Reward = 9.0
# Episode 188: Total Reward = 22.0
# Episode 189: Total Reward = 16.0
# Episode 190: Total Reward = 55.0
# Episode 191: Total Reward = 60.0
# Episode 192: Total Reward = 30.0
# Episode 193: Total Reward = 20.0
# Episode 194: Total Reward = 25.0
# Episode 195: Total Reward = 14.0
# Episode 196: Total Reward = 12.0
# Episode 197: Total Reward = 20.0
# Episode 198: Total Reward = 15.0
# Episode 199: Total Reward = 39.0
# Episode 200: Total Reward = 22.0
# Episode 201: Total Reward = 28.0
# Episode 202: Total Reward = 12.0
# Episode 203: Total Reward = 19.0
# Episode 204: Total Reward = 9.0
# Episode 205: Total Reward = 23.0
# Episode 206: Total Reward = 11.0
# Episode 207: Total Reward = 26.0
# Episode 208: Total Reward = 19.0
# Episode 209: Total Reward = 18.0
# Episode 210: Total Reward = 15.0
# Episode 211: Total Reward = 13.0
# Episode 212: Total Reward = 21.0
# Episode 213: Total Reward = 10.0
# Episode 214: Total Reward = 11.0
# Episode 215: Total Reward = 10.0
# Episode 216: Total Reward = 13.0
# Episode 217: Total Reward = 17.0
# Episode 218: Total Reward = 11.0
# Episode 219: Total Reward = 15.0
# Episode 220: Total Reward = 15.0
# Episode 221: Total Reward = 14.0
# Episode 222: Total Reward = 16.0
# Episode 223: Total Reward = 12.0
# Episode 224: Total Reward = 17.0
# Episode 225: Total Reward = 12.0
# Episode 226: Total Reward = 13.0
# Episode 227: Total Reward = 15.0
# Episode 228: Total Reward = 17.0
# Episode 229: Total Reward = 23.0
# Episode 230: Total Reward = 14.0
# Episode 231: Total Reward = 36.0
# Episode 232: Total Reward = 13.0
# Episode 233: Total Reward = 18.0
# Episode 234: Total Reward = 51.0
# Episode 235: Total Reward = 29.0
# Episode 236: Total Reward = 20.0
# Episode 237: Total Reward = 17.0
# Episode 238: Total Reward = 21.0
# Episode 239: Total Reward = 10.0
# Episode 240: Total Reward = 18.0
# Episode 241: Total Reward = 27.0
# Episode 242: Total Reward = 14.0
# Episode 243: Total Reward = 84.0
# Episode 244: Total Reward = 16.0
# Episode 245: Total Reward = 15.0
# Episode 246: Total Reward = 17.0
# Episode 247: Total Reward = 13.0
# Episode 248: Total Reward = 11.0
# Episode 249: Total Reward = 20.0
# Episode 250: Total Reward = 25.0
# Episode 251: Total Reward = 16.0
# Episode 252: Total Reward = 14.0
# Episode 253: Total Reward = 10.0
# Episode 254: Total Reward = 14.0
# Episode 255: Total Reward = 23.0
# Episode 256: Total Reward = 39.0
# Episode 257: Total Reward = 22.0
# Episode 258: Total Reward = 38.0
# Episode 259: Total Reward = 56.0
# Episode 260: Total Reward = 25.0
# Episode 261: Total Reward = 11.0
# Episode 262: Total Reward = 57.0
# Episode 263: Total Reward = 18.0
# Episode 264: Total Reward = 31.0
# Episode 265: Total Reward = 16.0
# Episode 266: Total Reward = 16.0
# Episode 267: Total Reward = 29.0
# Episode 268: Total Reward = 26.0
# Episode 269: Total Reward = 29.0
# Episode 270: Total Reward = 20.0
# Episode 271: Total Reward = 38.0
# Episode 272: Total Reward = 16.0
# Episode 273: Total Reward = 23.0
# Episode 274: Total Reward = 48.0
# Episode 275: Total Reward = 95.0
# Episode 276: Total Reward = 11.0
# Episode 277: Total Reward = 25.0
# Episode 278: Total Reward = 80.0
# Episode 279: Total Reward = 14.0
# Episode 280: Total Reward = 14.0
# Episode 281: Total Reward = 21.0
# Episode 282: Total Reward = 16.0
# Episode 283: Total Reward = 22.0
# Episode 284: Total Reward = 42.0
# Episode 285: Total Reward = 22.0
# Episode 286: Total Reward = 20.0
# Episode 287: Total Reward = 16.0
# Episode 288: Total Reward = 15.0
# Episode 289: Total Reward = 26.0
# Episode 290: Total Reward = 32.0
# Episode 291: Total Reward = 60.0
# Episode 292: Total Reward = 12.0
# Episode 293: Total Reward = 54.0
# Episode 294: Total Reward = 26.0
# Episode 295: Total Reward = 13.0
# Episode 296: Total Reward = 19.0
# Episode 297: Total Reward = 13.0
# Episode 298: Total Reward = 32.0
# Episode 299: Total Reward = 30.0
# Episode 300: Total Reward = 21.0
# Episode 301: Total Reward = 18.0
# Episode 302: Total Reward = 40.0
# Episode 303: Total Reward = 61.0
# Episode 304: Total Reward = 19.0
# Episode 305: Total Reward = 62.0
# Episode 306: Total Reward = 52.0
# Episode 307: Total Reward = 34.0
# Episode 308: Total Reward = 16.0
# Episode 309: Total Reward = 18.0
# Episode 310: Total Reward = 92.0
# Episode 311: Total Reward = 16.0
# Episode 312: Total Reward = 21.0
# Episode 313: Total Reward = 40.0
# Episode 314: Total Reward = 27.0
# Episode 315: Total Reward = 19.0
# Episode 316: Total Reward = 24.0
# Episode 317: Total Reward = 17.0
# Episode 318: Total Reward = 124.0
# Episode 319: Total Reward = 28.0
# Episode 320: Total Reward = 37.0
# Episode 321: Total Reward = 22.0
# Episode 322: Total Reward = 35.0
# Episode 323: Total Reward = 18.0
# Episode 324: Total Reward = 25.0
# Episode 325: Total Reward = 21.0
# Episode 326: Total Reward = 15.0
# Episode 327: Total Reward = 47.0
# Episode 328: Total Reward = 23.0
# Episode 329: Total Reward = 42.0
# Episode 330: Total Reward = 12.0
# Episode 331: Total Reward = 18.0
# Episode 332: Total Reward = 84.0
# Episode 333: Total Reward = 15.0
# Episode 334: Total Reward = 34.0
# Episode 335: Total Reward = 15.0
# Episode 336: Total Reward = 46.0
# Episode 337: Total Reward = 32.0
# Episode 338: Total Reward = 41.0
# Episode 339: Total Reward = 49.0
# Episode 340: Total Reward = 40.0
# Episode 341: Total Reward = 58.0
# Episode 342: Total Reward = 23.0
# Episode 343: Total Reward = 24.0
# Episode 344: Total Reward = 38.0
# Episode 345: Total Reward = 54.0
# Episode 346: Total Reward = 31.0
# Episode 347: Total Reward = 20.0
# Episode 348: Total Reward = 30.0
# Episode 349: Total Reward = 17.0
# Episode 350: Total Reward = 14.0
# Episode 351: Total Reward = 54.0
# Episode 352: Total Reward = 71.0
# Episode 353: Total Reward = 65.0
# Episode 354: Total Reward = 18.0
# Episode 355: Total Reward = 33.0
# Episode 356: Total Reward = 12.0
# Episode 357: Total Reward = 25.0
# Episode 358: Total Reward = 39.0
# Episode 359: Total Reward = 24.0
# Episode 360: Total Reward = 30.0
# Episode 361: Total Reward = 55.0
# Episode 362: Total Reward = 28.0
# Episode 363: Total Reward = 63.0
# Episode 364: Total Reward = 14.0
# Episode 365: Total Reward = 49.0
# Episode 366: Total Reward = 25.0
# Episode 367: Total Reward = 26.0
# Episode 368: Total Reward = 21.0
# Episode 369: Total Reward = 21.0
# Episode 370: Total Reward = 15.0
# Episode 371: Total Reward = 50.0
# Episode 372: Total Reward = 26.0
# Episode 373: Total Reward = 20.0
# Episode 374: Total Reward = 19.0
# Episode 375: Total Reward = 23.0
# Episode 376: Total Reward = 86.0
# Episode 377: Total Reward = 18.0
# Episode 378: Total Reward = 42.0
# Episode 379: Total Reward = 118.0
# Episode 380: Total Reward = 39.0
# Episode 381: Total Reward = 32.0
# Episode 382: Total Reward = 30.0
# Episode 383: Total Reward = 34.0
# Episode 384: Total Reward = 35.0
# Episode 385: Total Reward = 36.0
# Episode 386: Total Reward = 32.0
# Episode 387: Total Reward = 18.0
# Episode 388: Total Reward = 38.0
# Episode 389: Total Reward = 16.0
# Episode 390: Total Reward = 50.0
# Episode 391: Total Reward = 23.0
# Episode 392: Total Reward = 17.0
# Episode 393: Total Reward = 92.0
# Episode 394: Total Reward = 22.0
# Episode 395: Total Reward = 29.0
# Episode 396: Total Reward = 17.0
# Episode 397: Total Reward = 20.0
# Episode 398: Total Reward = 15.0
# Episode 399: Total Reward = 68.0
# Episode 400: Total Reward = 23.0
# Episode 401: Total Reward = 26.0
# Episode 402: Total Reward = 48.0
# Episode 403: Total Reward = 26.0
# Episode 404: Total Reward = 16.0
# Episode 405: Total Reward = 136.0
# Episode 406: Total Reward = 28.0
# Episode 407: Total Reward = 38.0
# Episode 408: Total Reward = 42.0
# Episode 409: Total Reward = 51.0
# Episode 410: Total Reward = 22.0
# Episode 411: Total Reward = 15.0
# Episode 412: Total Reward = 16.0
# Episode 413: Total Reward = 36.0
# Episode 414: Total Reward = 39.0
# Episode 415: Total Reward = 40.0
# Episode 416: Total Reward = 17.0
# Episode 417: Total Reward = 34.0
# Episode 418: Total Reward = 30.0
# Episode 419: Total Reward = 33.0
# Episode 420: Total Reward = 20.0
# Episode 421: Total Reward = 53.0
# Episode 422: Total Reward = 27.0
# Episode 423: Total Reward = 36.0
# Episode 424: Total Reward = 32.0
# Episode 425: Total Reward = 83.0
# Episode 426: Total Reward = 34.0
# Episode 427: Total Reward = 28.0
# Episode 428: Total Reward = 33.0
# Episode 429: Total Reward = 37.0
# Episode 430: Total Reward = 20.0
# Episode 431: Total Reward = 36.0
# Episode 432: Total Reward = 73.0
# Episode 433: Total Reward = 110.0
# Episode 434: Total Reward = 19.0
# Episode 435: Total Reward = 102.0
# Episode 436: Total Reward = 36.0
# Episode 437: Total Reward = 131.0
# Episode 438: Total Reward = 19.0
# Episode 439: Total Reward = 18.0
# Episode 440: Total Reward = 22.0
# Episode 441: Total Reward = 20.0
# Episode 442: Total Reward = 17.0
# Episode 443: Total Reward = 40.0
# Episode 444: Total Reward = 21.0
# Episode 445: Total Reward = 31.0
# Episode 446: Total Reward = 88.0
# Episode 447: Total Reward = 18.0
# Episode 448: Total Reward = 41.0
# Episode 449: Total Reward = 37.0
# Episode 450: Total Reward = 26.0
# Episode 451: Total Reward = 20.0
# Episode 452: Total Reward = 14.0
# Episode 453: Total Reward = 22.0
# Episode 454: Total Reward = 24.0
# Episode 455: Total Reward = 84.0
# Episode 456: Total Reward = 23.0
# Episode 457: Total Reward = 62.0
# Episode 458: Total Reward = 78.0
# Episode 459: Total Reward = 21.0
# Episode 460: Total Reward = 27.0
# Episode 461: Total Reward = 24.0
# Episode 462: Total Reward = 57.0
# Episode 463: Total Reward = 25.0
# Episode 464: Total Reward = 15.0
# Episode 465: Total Reward = 81.0
# Episode 466: Total Reward = 11.0
# Episode 467: Total Reward = 24.0
# Episode 468: Total Reward = 14.0
# Episode 469: Total Reward = 38.0
# Episode 470: Total Reward = 32.0
# Episode 471: Total Reward = 66.0
# Episode 472: Total Reward = 62.0
# Episode 473: Total Reward = 16.0
# Episode 474: Total Reward = 56.0
# Episode 475: Total Reward = 21.0
# Episode 476: Total Reward = 66.0
# Episode 477: Total Reward = 45.0
# Episode 478: Total Reward = 48.0
# Episode 479: Total Reward = 74.0
# Episode 480: Total Reward = 18.0
# Episode 481: Total Reward = 32.0
# Episode 482: Total Reward = 26.0
# Episode 483: Total Reward = 85.0
# Episode 484: Total Reward = 29.0
# Episode 485: Total Reward = 13.0
# Episode 486: Total Reward = 25.0
# Episode 487: Total Reward = 23.0
# Episode 488: Total Reward = 22.0
# Episode 489: Total Reward = 49.0
# Episode 490: Total Reward = 54.0
# Episode 491: Total Reward = 31.0
# Episode 492: Total Reward = 86.0
# Episode 493: Total Reward = 21.0
# Episode 494: Total Reward = 85.0
# Episode 495: Total Reward = 143.0
# Episode 496: Total Reward = 86.0
# Episode 497: Total Reward = 25.0
# Episode 498: Total Reward = 16.0
# Episode 499: Total Reward = 21.0
# Episode 500: Total Reward = 27.0
# Episode 501: Total Reward = 64.0
# Episode 502: Total Reward = 12.0
# Episode 503: Total Reward = 29.0
# Episode 504: Total Reward = 26.0
# Episode 505: Total Reward = 55.0
# Episode 506: Total Reward = 20.0
# Episode 507: Total Reward = 84.0
# Episode 508: Total Reward = 14.0
# Episode 509: Total Reward = 210.0
# Episode 510: Total Reward = 15.0
# Episode 511: Total Reward = 23.0
# Episode 512: Total Reward = 23.0
# Episode 513: Total Reward = 19.0
# Episode 514: Total Reward = 134.0
# Episode 515: Total Reward = 83.0
# Episode 516: Total Reward = 30.0
# Episode 517: Total Reward = 32.0
# Episode 518: Total Reward = 25.0
# Episode 519: Total Reward = 22.0
# Episode 520: Total Reward = 31.0
# Episode 521: Total Reward = 23.0
# Episode 522: Total Reward = 37.0
# Episode 523: Total Reward = 73.0
# Episode 524: Total Reward = 73.0
# Episode 525: Total Reward = 19.0
# Episode 526: Total Reward = 39.0
# Episode 527: Total Reward = 45.0
# Episode 528: Total Reward = 48.0
# Episode 529: Total Reward = 97.0
# Episode 530: Total Reward = 24.0
# Episode 531: Total Reward = 25.0
# Episode 532: Total Reward = 74.0
# Episode 533: Total Reward = 239.0
# Episode 534: Total Reward = 44.0
# Episode 535: Total Reward = 43.0
# Episode 536: Total Reward = 36.0
# Episode 537: Total Reward = 21.0
# Episode 538: Total Reward = 29.0
# Episode 539: Total Reward = 19.0
# Episode 540: Total Reward = 77.0
# Episode 541: Total Reward = 72.0
# Episode 542: Total Reward = 21.0
# Episode 543: Total Reward = 36.0
# Episode 544: Total Reward = 38.0
# Episode 545: Total Reward = 63.0
# Episode 546: Total Reward = 36.0
# Episode 547: Total Reward = 29.0
# Episode 548: Total Reward = 40.0
# Episode 549: Total Reward = 33.0
# Episode 550: Total Reward = 34.0
# Episode 551: Total Reward = 22.0
# Episode 552: Total Reward = 72.0
# Episode 553: Total Reward = 63.0
# Episode 554: Total Reward = 22.0
# Episode 555: Total Reward = 94.0
# Episode 556: Total Reward = 26.0
# Episode 557: Total Reward = 68.0
# Episode 558: Total Reward = 27.0
# Episode 559: Total Reward = 15.0
# Episode 560: Total Reward = 41.0
# Episode 561: Total Reward = 40.0
# Episode 562: Total Reward = 49.0
# Episode 563: Total Reward = 46.0
# Episode 564: Total Reward = 19.0
# Episode 565: Total Reward = 59.0
# Episode 566: Total Reward = 37.0
# Episode 567: Total Reward = 186.0
# Episode 568: Total Reward = 95.0
# Episode 569: Total Reward = 90.0
# Episode 570: Total Reward = 118.0
# Episode 571: Total Reward = 15.0
# Episode 572: Total Reward = 15.0
# Episode 573: Total Reward = 56.0
# Episode 574: Total Reward = 20.0
# Episode 575: Total Reward = 15.0
# Episode 576: Total Reward = 43.0
# Episode 577: Total Reward = 157.0
# Episode 578: Total Reward = 33.0
# Episode 579: Total Reward = 115.0
# Episode 580: Total Reward = 62.0
# Episode 581: Total Reward = 16.0
# Episode 582: Total Reward = 42.0
# Episode 583: Total Reward = 29.0
# Episode 584: Total Reward = 47.0
# Episode 585: Total Reward = 30.0
# Episode 586: Total Reward = 144.0
# Episode 587: Total Reward = 63.0
# Episode 588: Total Reward = 30.0
# Episode 589: Total Reward = 42.0
# Episode 590: Total Reward = 79.0
# Episode 591: Total Reward = 21.0
# Episode 592: Total Reward = 48.0
# Episode 593: Total Reward = 31.0
# Episode 594: Total Reward = 20.0
# Episode 595: Total Reward = 31.0
# Episode 596: Total Reward = 84.0
# Episode 597: Total Reward = 58.0
# Episode 598: Total Reward = 134.0
# Episode 599: Total Reward = 121.0
# Episode 600: Total Reward = 126.0
# Episode 601: Total Reward = 51.0
# Episode 602: Total Reward = 134.0
# Episode 603: Total Reward = 55.0
# Episode 604: Total Reward = 37.0
# Episode 605: Total Reward = 31.0
# Episode 606: Total Reward = 29.0
# Episode 607: Total Reward = 37.0
# Episode 608: Total Reward = 32.0
# Episode 609: Total Reward = 40.0
# Episode 610: Total Reward = 25.0
# Episode 611: Total Reward = 49.0
# Episode 612: Total Reward = 28.0
# Episode 613: Total Reward = 19.0
# Episode 614: Total Reward = 70.0
# Episode 615: Total Reward = 23.0
# Episode 616: Total Reward = 126.0
# Episode 617: Total Reward = 35.0
# Episode 618: Total Reward = 26.0
# Episode 619: Total Reward = 37.0
# Episode 620: Total Reward = 39.0
# Episode 621: Total Reward = 40.0
# Episode 622: Total Reward = 41.0
# Episode 623: Total Reward = 74.0
# Episode 624: Total Reward = 34.0
# Episode 625: Total Reward = 29.0
# Episode 626: Total Reward = 47.0
# Episode 627: Total Reward = 33.0
# Episode 628: Total Reward = 46.0
# Episode 629: Total Reward = 36.0
# Episode 630: Total Reward = 37.0
# Episode 631: Total Reward = 29.0
# Episode 632: Total Reward = 81.0
# Episode 633: Total Reward = 31.0
# Episode 634: Total Reward = 20.0
# Episode 635: Total Reward = 25.0
# Episode 636: Total Reward = 33.0
# Episode 637: Total Reward = 71.0
# Episode 638: Total Reward = 112.0
# Episode 639: Total Reward = 132.0
# Episode 640: Total Reward = 133.0
# Episode 641: Total Reward = 121.0
# Episode 642: Total Reward = 24.0
# Episode 643: Total Reward = 181.0
# Episode 644: Total Reward = 217.0
# Episode 645: Total Reward = 25.0
# Episode 646: Total Reward = 32.0
# Episode 647: Total Reward = 29.0
# Episode 648: Total Reward = 54.0
# Episode 649: Total Reward = 53.0
# Episode 650: Total Reward = 48.0
# Episode 651: Total Reward = 200.0
# Episode 652: Total Reward = 44.0
# Episode 653: Total Reward = 43.0
# Episode 654: Total Reward = 25.0
# Episode 655: Total Reward = 71.0
# Episode 656: Total Reward = 173.0
# Episode 657: Total Reward = 102.0
# Episode 658: Total Reward = 23.0
# Episode 659: Total Reward = 47.0
# Episode 660: Total Reward = 80.0
# Episode 661: Total Reward = 78.0
# Episode 662: Total Reward = 20.0
# Episode 663: Total Reward = 119.0
# Episode 664: Total Reward = 168.0
# Episode 665: Total Reward = 18.0
# Episode 666: Total Reward = 22.0
# Episode 667: Total Reward = 113.0
# Episode 668: Total Reward = 66.0
# Episode 669: Total Reward = 88.0
# Episode 670: Total Reward = 122.0
# Episode 671: Total Reward = 25.0
# Episode 672: Total Reward = 46.0
# Episode 673: Total Reward = 113.0
# Episode 674: Total Reward = 163.0
# Episode 675: Total Reward = 31.0
# Episode 676: Total Reward = 25.0
# Episode 677: Total Reward = 35.0
# Episode 678: Total Reward = 72.0
# Episode 679: Total Reward = 22.0
# Episode 680: Total Reward = 149.0
# Episode 681: Total Reward = 75.0
# Episode 682: Total Reward = 89.0
# Episode 683: Total Reward = 106.0
# Episode 684: Total Reward = 18.0
# Episode 685: Total Reward = 21.0
# Episode 686: Total Reward = 29.0
# Episode 687: Total Reward = 59.0
# Episode 688: Total Reward = 45.0
# Episode 689: Total Reward = 98.0
# Episode 690: Total Reward = 63.0
# Episode 691: Total Reward = 24.0
# Episode 692: Total Reward = 21.0
# Episode 693: Total Reward = 19.0
# Episode 694: Total Reward = 32.0
# Episode 695: Total Reward = 76.0
# Episode 696: Total Reward = 128.0
# Episode 697: Total Reward = 161.0
# Episode 698: Total Reward = 47.0
# Episode 699: Total Reward = 74.0
# Episode 700: Total Reward = 138.0
# Episode 701: Total Reward = 47.0
# Episode 702: Total Reward = 41.0
# Episode 703: Total Reward = 111.0
# Episode 704: Total Reward = 40.0
# Episode 705: Total Reward = 41.0
# Episode 706: Total Reward = 183.0
# Episode 707: Total Reward = 34.0
# Episode 708: Total Reward = 46.0
# Episode 709: Total Reward = 19.0
# Episode 710: Total Reward = 70.0
# Episode 711: Total Reward = 39.0
# Episode 712: Total Reward = 42.0
# Episode 713: Total Reward = 89.0
# Episode 714: Total Reward = 181.0
# Episode 715: Total Reward = 30.0
# Episode 716: Total Reward = 64.0
# Episode 717: Total Reward = 183.0
# Episode 718: Total Reward = 118.0
# Episode 719: Total Reward = 34.0
# Episode 720: Total Reward = 49.0
# Episode 721: Total Reward = 76.0
# Episode 722: Total Reward = 96.0
# Episode 723: Total Reward = 119.0
# Episode 724: Total Reward = 324.0
# Episode 725: Total Reward = 17.0
# Episode 726: Total Reward = 17.0
# Episode 727: Total Reward = 28.0
# Episode 728: Total Reward = 21.0
# Episode 729: Total Reward = 11.0
# Episode 730: Total Reward = 101.0
# Episode 731: Total Reward = 41.0
# Episode 732: Total Reward = 60.0
# Episode 733: Total Reward = 51.0
# Episode 734: Total Reward = 30.0
# Episode 735: Total Reward = 141.0
# Episode 736: Total Reward = 23.0
# Episode 737: Total Reward = 84.0
# Episode 738: Total Reward = 126.0
# Episode 739: Total Reward = 27.0
# Episode 740: Total Reward = 75.0
# Episode 741: Total Reward = 62.0
# Episode 742: Total Reward = 86.0
# Episode 743: Total Reward = 34.0
# Episode 744: Total Reward = 66.0
# Episode 745: Total Reward = 132.0
# Episode 746: Total Reward = 80.0
# Episode 747: Total Reward = 104.0
# Episode 748: Total Reward = 34.0
# Episode 749: Total Reward = 35.0
# Episode 750: Total Reward = 45.0
# Episode 751: Total Reward = 138.0
# Episode 752: Total Reward = 104.0
# Episode 753: Total Reward = 22.0
# Episode 754: Total Reward = 170.0
# Episode 755: Total Reward = 46.0
# Episode 756: Total Reward = 166.0
# Episode 757: Total Reward = 139.0
# Episode 758: Total Reward = 184.0
# Episode 759: Total Reward = 53.0
# Episode 760: Total Reward = 69.0
# Episode 761: Total Reward = 45.0
# Episode 762: Total Reward = 15.0
# Episode 763: Total Reward = 106.0
# Episode 764: Total Reward = 23.0
# Episode 765: Total Reward = 54.0
# Episode 766: Total Reward = 61.0
# Episode 767: Total Reward = 80.0
# Episode 768: Total Reward = 34.0
# Episode 769: Total Reward = 78.0
# Episode 770: Total Reward = 28.0
# Episode 771: Total Reward = 104.0
# Episode 772: Total Reward = 34.0
# Episode 773: Total Reward = 21.0
# Episode 774: Total Reward = 128.0
# Episode 775: Total Reward = 54.0
# Episode 776: Total Reward = 34.0
# Episode 777: Total Reward = 147.0
# Episode 778: Total Reward = 60.0
# Episode 779: Total Reward = 26.0
# Episode 780: Total Reward = 142.0
# Episode 781: Total Reward = 53.0
# Episode 782: Total Reward = 28.0
# Episode 783: Total Reward = 124.0
# Episode 784: Total Reward = 129.0
# Episode 785: Total Reward = 32.0
# Episode 786: Total Reward = 22.0
# Episode 787: Total Reward = 27.0
# Episode 788: Total Reward = 22.0
# Episode 789: Total Reward = 18.0
# Episode 790: Total Reward = 32.0
# Episode 791: Total Reward = 112.0
# Episode 792: Total Reward = 110.0
# Episode 793: Total Reward = 121.0
# Episode 794: Total Reward = 106.0
# Episode 795: Total Reward = 22.0
# Episode 796: Total Reward = 108.0
# Episode 797: Total Reward = 31.0
# Episode 798: Total Reward = 92.0
# Episode 799: Total Reward = 97.0
# Episode 800: Total Reward = 18.0
# Episode 801: Total Reward = 41.0
# Episode 802: Total Reward = 37.0
# Episode 803: Total Reward = 39.0
# Episode 804: Total Reward = 48.0
# Episode 805: Total Reward = 145.0
# Episode 806: Total Reward = 161.0
# Episode 807: Total Reward = 144.0
# Episode 808: Total Reward = 117.0
# Episode 809: Total Reward = 135.0
# Episode 810: Total Reward = 22.0
# Episode 811: Total Reward = 26.0
# Episode 812: Total Reward = 55.0
# Episode 813: Total Reward = 65.0
# Episode 814: Total Reward = 110.0
# Episode 815: Total Reward = 55.0
# Episode 816: Total Reward = 120.0
# Episode 817: Total Reward = 102.0
# Episode 818: Total Reward = 185.0
# Episode 819: Total Reward = 51.0
# Episode 820: Total Reward = 163.0
# Episode 821: Total Reward = 150.0
# Episode 822: Total Reward = 162.0
# Episode 823: Total Reward = 78.0
# Episode 824: Total Reward = 118.0
# Episode 825: Total Reward = 71.0
# Episode 826: Total Reward = 264.0
# Episode 827: Total Reward = 24.0
# Episode 828: Total Reward = 25.0
# Episode 829: Total Reward = 90.0
# Episode 830: Total Reward = 27.0
# Episode 831: Total Reward = 71.0
# Episode 832: Total Reward = 110.0
# Episode 833: Total Reward = 16.0
# Episode 834: Total Reward = 26.0
# Episode 835: Total Reward = 61.0
# Episode 836: Total Reward = 42.0
# Episode 837: Total Reward = 111.0
# Episode 838: Total Reward = 33.0
# Episode 839: Total Reward = 61.0
# Episode 840: Total Reward = 139.0
# Episode 841: Total Reward = 114.0
# Episode 842: Total Reward = 155.0
# Episode 843: Total Reward = 184.0
# Episode 844: Total Reward = 72.0
# Episode 845: Total Reward = 143.0
# Episode 846: Total Reward = 86.0
# Episode 847: Total Reward = 78.0
# Episode 848: Total Reward = 28.0
# Episode 849: Total Reward = 25.0
# Episode 850: Total Reward = 109.0
# Episode 851: Total Reward = 98.0
# Episode 852: Total Reward = 131.0
# Episode 853: Total Reward = 123.0
# Episode 854: Total Reward = 29.0
# Episode 855: Total Reward = 27.0
# Episode 856: Total Reward = 121.0
# Episode 857: Total Reward = 84.0
# Episode 858: Total Reward = 66.0
# Episode 859: Total Reward = 27.0
# Episode 860: Total Reward = 66.0
# Episode 861: Total Reward = 80.0
# Episode 862: Total Reward = 62.0
# Episode 863: Total Reward = 63.0
# Episode 864: Total Reward = 126.0
# Episode 865: Total Reward = 136.0
# Episode 866: Total Reward = 114.0
# Episode 867: Total Reward = 59.0
# Episode 868: Total Reward = 40.0
# Episode 869: Total Reward = 122.0
# Episode 870: Total Reward = 47.0
# Episode 871: Total Reward = 212.0
# Episode 872: Total Reward = 32.0
# Episode 873: Total Reward = 23.0
# Episode 874: Total Reward = 129.0
# Episode 875: Total Reward = 27.0
# Episode 876: Total Reward = 46.0
# Episode 877: Total Reward = 254.0
# Episode 878: Total Reward = 37.0
# Episode 879: Total Reward = 116.0
# Episode 880: Total Reward = 136.0
# Episode 881: Total Reward = 19.0
# Episode 882: Total Reward = 83.0
# Episode 883: Total Reward = 17.0
# Episode 884: Total Reward = 114.0
# Episode 885: Total Reward = 115.0
# Episode 886: Total Reward = 20.0
# Episode 887: Total Reward = 108.0
# Episode 888: Total Reward = 23.0
# Episode 889: Total Reward = 24.0
# Episode 890: Total Reward = 131.0
# Episode 891: Total Reward = 146.0
# Episode 892: Total Reward = 97.0
# Episode 893: Total Reward = 122.0

# %% [markdown]
# Looking at the reward, you can see that the agent gets properly trained. Now I can start with the autocomplete. While looking for a good dataset on kaggle, I found a english word frequency [dataset](https://www.kaggle.com/datasets/rtatman/english-word-frequency/data) containing 333333 of the most frequently used words according to Google Web Trillion Word Corpus. I want to remove all single letter words from the dataset as most of these are most likely accidental searches and there is no point on training the agent on single letters as there is no second letter to predict. I also removed words longer than 16 characters so I could later on pad all words to a reasonable size. 10 was a bit too short as some common words will be longer than 10 character but 15 was way more reasonable.

# %% [markdown]
# I wrote a small script that loads in the dataset into a dataframe using pandas, creates a new dataframe containing all rows where the word length is longer than one and and shorter than 16 and saves it to a new file.

# %%
import pandas as pd

input_file = "dataset.csv"
output_file = "dataset_clean.csv"

df = pd.read_csv(input_file)
df_filtered = df[(df['word'].str.len() > 1) & (df['word'].str.len() <= 15)]

df_filtered.to_csv(output_file, index=False)

# %% [markdown]
# My plan for training is taking a random word from the dataset, giving a small portion of the word to the agent as the state, having the agent guess the next letter and then checking if the guess is correct. If the agent gets the answer right, it will get 1 reward, otherwise it doesn't get any rewards.

# %% [markdown]
# I'm planning on converting the characters to integers. I hope that this way the agent will be better at understanding the alphabet. encoding like this is already widely [used](https://www.iterate.ai/ai-glossary/what-is-encode-technology) in generative AI

# %% [markdown]
# Here's the code I use to create 2 maps for converting between the characters and the integers

# %%
alphabet = list("abcdefghijklmnopqrstuvwxyz")
char_to_int = {c: i for i, c in enumerate(alphabet)}
idx_to_char = {i: c for c, i in char_to_int.items()}
vocab_size = len(alphabet)

print(char_to_int)
# Out:
# {'a': 0, 'b': 1, 'c': 2, 'd': 3, 'e': 4, 'f': 5, 'g': 6, 'h': 7, 'i': 8, 'j': 9, 'k': 10, 'l': 11, 'm': 12, 'n': 13, 'o': 14, 'p': 15, 'q': 16, 'r': 17, 's': 18, 't': 19, 'u': 20, 'v': 21, 'w': 22, 'x': 23, 'y': 24, 'z': 25}

# %% [markdown]
# Now I have a finished basic training loop, one problem I ran into though is that my torch module did not support the encoded text that I was providing it. I had to update it to fix this issue. The new module now adds an embedding layer. the sizes of the linear layers are also adjusted to fit.

# %%
class ActorCriticV2(nn.Module):

    def __init__(self, nb_actions, embed_dim=32, hidden_size=64):
        super().__init__()
        self.embedding = nn.Embedding(nb_actions, embed_dim)
        self.rnn = nn.GRU(embed_dim, hidden_size, batch_first=True)

        self.head = nn.Sequential(
            nn.Linear(hidden_size, 64), nn.Tanh(),
            nn.Linear(64, 64), nn.Tanh()
        )
        self.actor = nn.Linear(64, nb_actions)
        self.critic = nn.Linear(64, 1)
    
    def forward(self, x):
        x = self.embedding(x)
        _, h = self.rnn(x)
        h = h.squeeze(0)

        h = self.head(h)
        return self.actor(h), self.critic(h)

# %% [markdown]
# I also had to update the PPOAgent because it was converting the states to float which was causing an error with the updated module.

# %%
import torch
import numpy as np

class PPOAgentV2:
    def __init__(self, nb_actions, device='cpu', gamma=0.99, lam=0.95, clip_eps=0.2, lr=2.5e-4, epochs=4, batch_size=64):
        self.device = device
        self.gamma = gamma
        self.lam = lam
        self.clip_eps = clip_eps
        self.epochs = epochs
        self.batch_size = batch_size

        self.model = ActorCriticV2(nb_actions).to(device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)

    def get_action_and_value(self, state):
        logits, value = self.model(state)
        dist = Categorical(logits=logits)
        action = dist.sample()
        log_prob = dist.log_prob(action)
        return action, log_prob, value.squeeze(-1)

    def compute_gae(self, rewards, values, dones, next_value):
        values = np.append(values, next_value)
        gae = 0
        returns = []
        for t in reversed(range(len(rewards))):
            delta = rewards[t] + self.gamma * values[t + 1] * (1 - dones[t]) - values[t]
            gae = delta + self.gamma * self.lam * (1 - dones[t]) * gae
            returns.insert(0, gae + values[t])
        return returns

    def ppo_update(self, states, actions, log_probs, returns, values):
        advantages = returns - values
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        for _ in range(self.epochs):
            indices = np.arange(len(states))
            np.random.shuffle(indices)

            for i in range(0, len(states), self.batch_size):
                idx = indices[i:i+self.batch_size]
                s_batch = torch.tensor(states[idx]).to(self.device) # Removed dtype=torch.float32 here to fix the crash
                a_batch = torch.tensor(actions[idx]).to(self.device)
                old_log_probs_batch = torch.tensor(log_probs[idx]).to(self.device)
                ret_batch = torch.tensor(returns[idx], dtype=torch.float32).to(self.device)
                adv_batch = torch.tensor(advantages[idx], dtype=torch.float32).to(self.device)

                logits, value = self.model(s_batch)
                dist = Categorical(logits=logits)
                entropy = dist.entropy().mean()
                new_log_probs = dist.log_prob(a_batch)

                ratio = (new_log_probs - old_log_probs_batch).exp()
                surr1 = ratio * adv_batch
                # Clipping for stability
                surr2 = torch.clamp(ratio, 1.0 - self.clip_eps, 1.0 + self.clip_eps) * adv_batch

                policy_loss = -torch.min(surr1, surr2).mean()
                value_loss = F.mse_loss(value.squeeze(-1), ret_batch)
                loss = policy_loss + 0.5 * value_loss - 0.01 * entropy

                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()

# %% [markdown]
# Here is the training loop that I made the updated PPOAgent for

# %%
import torch
import random
import numpy as np
import pandas as pd

max_seq_len = 15
device = 'cuda' if torch.cuda.is_available() else 'cpu'

alphabet = list("abcdefghijklmnopqrstuvwxyz")
PAD_IDX = len(alphabet)  # 26
char_to_int = {c: i for i, c in enumerate(alphabet)}
int_to_char = {i: c for i, c in enumerate(alphabet)}
vocab_size = len(alphabet) + 1  # +1 for PAD

agent = PPOAgentV2(nb_actions=vocab_size, device=device)

words = pd.read_csv("dataset_clean.csv")['word'].str.lower().tolist()
words = [w for w in words if w.isalpha()]

for epoch in range(10): # made this shorter in the notebook for showcasing
    states, actions, log_probs, rewards, values, dones = [], [], [], [], [], []
    
    for _ in range(50):  # steps per epoch
        word = random.choice(words)
        for t in range(len(word) - 1):
            partial = word[:t]
            target_char = word[t]

            # Encode partial word
            state = [char_to_int[c] for c in partial]
            pad_len = max_seq_len - len(state)
            state += [PAD_IDX] * pad_len  # pad with PAD_IDX
            state_tensor = torch.tensor([state], dtype=torch.long).to(device)  # shape: [1, max_seq_len]

            # Get action from PPO
            action, log_prob, value = agent.get_action_and_value(state_tensor)
            guessed_char = int_to_char.get(action.item(), '?')
            correct = guessed_char == target_char
            reward = 1 if correct else 0

            # Store experience
            states.append(state)
            actions.append(action.item())
            log_probs.append(log_prob.item())
            rewards.append(reward)
            values.append(value.item())
            dones.append(False)

        dones[-1] = True  # End of word is end of episode

    # Bootstrap value for last step
    next_state = torch.tensor([states[-1]], dtype=torch.long).to(device)
    _, _, next_value = agent.get_action_and_value(next_state)
    returns = agent.compute_gae(rewards, values, dones, next_value.item())

    # Convert to arrays
    states = torch.tensor(states, dtype=torch.long)
    actions = np.array(actions)
    log_probs = np.array(log_probs)
    returns = np.array(returns)
    values = np.array(values)

    agent.ppo_update(states, actions, log_probs, returns, values)

    avg_reward = np.mean(rewards)
    print(f"Epoch {epoch}: Avg reward per step: {avg_reward:.2f}")
# Out:
# C:\Users\ralf2\AppData\Local\Temp\ipykernel_26912\93846100.py:43: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   s_batch = torch.tensor(states[idx]).to(self.device) # Removed dtype=torch.float32 here to fix the crash
# Epoch 0: Avg reward per step: 0.03
# Epoch 1: Avg reward per step: 0.02
# Epoch 2: Avg reward per step: 0.06
# Epoch 3: Avg reward per step: 0.05
# Epoch 4: Avg reward per step: 0.06
# Epoch 5: Avg reward per step: 0.04
# Epoch 6: Avg reward per step: 0.06
# Epoch 7: Avg reward per step: 0.05
# Epoch 8: Avg reward per step: 0.04
# Epoch 9: Avg reward per step: 0.06

# %% [markdown]
# The training loop now runs but my model cannot be saved at this point. I want to add saving/loading with a potential autosave every few episodes/epochs so I can test the model later for validation and train saved models more.

# %% [markdown]
# I added a saving and loading function to my PPOAgent. they use the **torch.save** and **torch.load** functions to save/load the model, optimizer and parameters

# %%
class PPOAgentV3:
    def __init__(self, nb_actions, device='cpu', gamma=0.99, lam=0.95, clip_eps=0.2, lr=2.5e-4, epochs=4, batch_size=64):
        self.device = device
        self.gamma = gamma
        self.lam = lam
        self.clip_eps = clip_eps
        self.epochs = epochs
        self.batch_size = batch_size

        self.model = ActorCriticV2(nb_actions).to(device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)

    def save(self, path):
        torch.save({
            'model_state_dict': self.model.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'hyperparams': {
                'gamma': self.gamma,
                'lam': self.lam,
                'clip_eps': self.clip_eps,
                'epochs': self.epochs,
                'batch_size': self.batch_size
            }
        }, path)
    
    def load(self, path):
        checkpoint = torch.load(path, map_location=self.device)
        self.model.load_state_dict(checkpoint['model_state_dict'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

        h = checkpoint.get('hyperparams', {})
        self.gamma = h.get('gamma', self.gamma)
        self.lam = h.get('lam', self.lam)
        self.clip_eps = h.get('clip_eps', self.clip_eps)
        self.epochs = h.get('epochs', self.epochs)
        self.batch_size = h.get('batch_size', self.batch_size)

    def get_action_and_value(self, state):
        logits, value = self.model(state)
        dist = Categorical(logits=logits)
        action = dist.sample()
        log_prob = dist.log_prob(action)
        return action, log_prob, value.squeeze(-1)

    def compute_gae(self, rewards, values, dones, next_value):
        values = np.append(values, next_value)
        gae = 0
        returns = []
        for t in reversed(range(len(rewards))):
            delta = rewards[t] + self.gamma * values[t + 1] * (1 - dones[t]) - values[t]
            gae = delta + self.gamma * self.lam * (1 - dones[t]) * gae
            returns.insert(0, gae + values[t])
        return returns

    def ppo_update(self, states, actions, log_probs, returns, values):
        advantages = returns - values
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        for _ in range(self.epochs):
            indices = np.arange(len(states))
            np.random.shuffle(indices)

            for i in range(0, len(states), self.batch_size):
                idx = indices[i:i+self.batch_size]
                s_batch = torch.tensor(states[idx]).to(self.device)
                a_batch = torch.tensor(actions[idx]).to(self.device)
                old_log_probs_batch = torch.tensor(log_probs[idx]).to(self.device)
                ret_batch = torch.tensor(returns[idx], dtype=torch.float32).to(self.device)
                adv_batch = torch.tensor(advantages[idx], dtype=torch.float32).to(self.device)

                logits, value = self.model(s_batch)
                dist = Categorical(logits=logits)
                entropy = dist.entropy().mean()
                new_log_probs = dist.log_prob(a_batch)

                ratio = (new_log_probs - old_log_probs_batch).exp()
                surr1 = ratio * adv_batch
                surr2 = torch.clamp(ratio, 1.0 - self.clip_eps, 1.0 + self.clip_eps) * adv_batch

                policy_loss = -torch.min(surr1, surr2).mean()
                value_loss = F.mse_loss(value.squeeze(-1), ret_batch)

                loss = policy_loss + 0.5 * value_loss - 0.01 * entropy

                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()

# %% [markdown]
# I then updated my training loop so it would save the model every 20 epochs. I trained the model overnight and after about 8160 epochs I ended up with 0.20 average reward. The reward was aroung 0.9 when I started and got up to about 0.15 after 30 minutes so it looks like I've hit some sort of limitation, either because the training data is too large or because my pytorch module could be inadequate. It might also just not be possible to get to 1 average reward because 2 words can start the same but still have a different next letter. at that point it is just up to the agent as to what next letter gets chosen

# %% [markdown]
# I made a script that allows me to input part of a word and have the agent pick the next letter for me. Even though the average reward is only about 0.20, it is still able to finish some words and in cases where it is wrong it often still picks a letter that could make sense

# %%
# Constants
max_seq_len = 15
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Character mappings
alphabet = list("abcdefghijklmnopqrstuvwxyz")
PAD_IDX = len(alphabet)  # 26
char_to_int = {c: i for i, c in enumerate(alphabet)}
int_to_char = {i: c for i, c in enumerate(alphabet)}

# Load the trained agent
agent = PPOAgentV3(nb_actions=len(alphabet) + 1, device=device)
agent.load('./training/model1/ppo_checkpoint_epoch_8160.pth')  # path to saved checkpoint with highest count

def predict_next_char(partial_word: str) -> str:
    partial_word = partial_word.lower()
    encoded = [char_to_int.get(c, PAD_IDX) for c in partial_word if c in char_to_int]
    if len(encoded) > max_seq_len:
        encoded = encoded[-max_seq_len:]  # keep only last max_seq_len characters
    else:
        encoded += [PAD_IDX] * (max_seq_len - len(encoded))  # pad to fixed length

    state_tensor = torch.tensor([encoded], dtype=torch.long).to(device)
    action, _, _ = agent.get_action_and_value(state_tensor)

    return int_to_char.get(action.item(), '')

if __name__ == "__main__":
    print("Word: alie")
    predicted_char = predict_next_char("alie")
    print(f"Predicted next character: {predicted_char}")

    print("Word: quarmir")
    predicted_char = predict_next_char("quagmir")
    print(f"Predicted next character: {predicted_char}")

    print("Word: past")
    predicted_char = predict_next_char("past")
    print(f"Predicted next character: {predicted_char}")

    print("Word: pirat")
    predicted_char = predict_next_char("pirat")
    print(f"Predicted next character: {predicted_char}")
# Out:
# Word: alie
# Predicted next character: n
# Word: quarmir
# Predicted next character: e
# Word: past
# Predicted next character: e
# Word: pirat
# Predicted next character: i

# %% [markdown]
# Now that I have the trained model and I can get it to generate a next letter, I need to validate it to see how reliable it is. I already know from training that it isn't super reliable but it would be better to get a calculated estimate for reliablility
